# %%
import pandas as pd
import requests
from io import StringIO
from pathlib import Path

print(pd.__version__)
# Out:
# 3.0.2

# %% [markdown]
# ## Получение набора данных по ссылке
#
# Скачиваем набор данных с сайта Минпромторга: https://minpromtorg.gov.ru/opendata/1000000001-meripoddergki/data-20260508-structure-20191213.csv
#
# Сохраняем его в директории data/raw.

# %%
url = "https://minpromtorg.gov.ru/opendata/1000000001-meripoddergki/data-20260508-structure-20191213.csv"
# my_user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()

print(f"Status: {response.status_code}")
print(f"Content-Type: {response.headers.get("Content-Tupe")}")
print(f"Previue: {response.text[:50]}")


# df = pd.read_csv(StringIO(response.text))

# print(df.dtypes)

# Путь для сохранения файла
RAW_DATA_PATH = Path("data/raw/supportmeas.csv")

# Сохраняем полученный набор данных локально.
# df.to_csv(RAW_DATA_PATH, index=False)
# Out:
# Status: 200
# Content-Type: None
# Previue: ID,URL,SMALL_NAME,FULL_NAME,NUMBER_NPA,DATE_NPA,NP
